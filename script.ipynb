# %%
import requests
import pandas as pd

# %%
url = "https://youtube138.p.rapidapi.com/channel/videos/"

querystring = {"id":"UCJ5v_MCY6GNUBTO8-D3XoAg","filter":"videos_latest","hl":"en","gl":"US"}

headers = {
	"x-rapidapi-key": "950922b3b4mshf8fa19a1a80c9bep121817jsne868362a71bc",
	"x-rapidapi-host": "youtube138.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

# %%
def retrieve_youtube_data():

    # All API parameters
    url = "https://youtube138.p.rapidapi.com/channel/videos/"

    querystring = {"id":"UCJ5v_MCY6GNUBTO8-D3XoAg","filter":"videos_latest","hl":"en","gl":"US"}

    headers = {
	"x-rapidapi-key": "950922b3b4mshf8fa19a1a80c9bep121817jsne868362a71bc",
	"x-rapidapi-host": "youtube138.p.rapidapi.com"
    }

    # Send a GET request to the API endpoint
    response = requests.get(url, headers=headers, params=querystring)

    # Show the response from the API call
    print(response)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the response content as JSON
        json_data = response.json()

        # Save the json to a csv file using pandas
        df = pd.json_normalize(json_data['contents'])
        df.to_csv("data.csv", index=False)
    else:
        print("there was an error")

# %%
retrieve_youtube_data()
# Out:
# <Response [200]>
# {'contents': [{'type': 'video', 'video': {'badges': [], 'isLiveNow': False, 'lengthSeconds': 196, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/QfWVpBzSZsA/mqdefault_6s.webp?du=3000&sqp=CLDqycsG&rs=AOn4CLAopdfjnHJmKBRunud5xyoNsJugWA', 'width': 320}], 'publishedTimeText': '3 hours ago', 'stats': {'views': 7224}, 'thumbnails': [{'height': 94, 'url': 'https://i.ytimg.com/vi/QfWVpBzSZsA/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBI62bBm1CjMdwqTKkA5bZ5tIV_hg', 'width': 168}, {'height': 110, 'url': 'https://i.ytimg.com/vi/QfWVpBzSZsA/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLD1ANCEG4omUR194w47be8CncVMig', 'width': 196}, {'height': 138, 'url': 'https://i.ytimg.com/vi/QfWVpBzSZsA/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB7INpDpui_yL0hM3-M78wqAQImgQ', 'width': 246}, {'height': 188, 'url': 'https://i.ytimg.com/vi/QfWVpBzSZsA/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCK3PUmx_JObYhj9RNHVUZuTc5zfw', 'width': 336}], 'title': 'Karmen Petrovic and Kali Armstrong battle in Evolve: WWE Evolve highlights, Jan. 21, 2026', 'videoId': 'QfWVpBzSZsA'}}, {'type': 'video', 'video': {'badges': [], 'isLiveNow': False, 'lengthSeconds': 1297, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/2MvyudXO0ew/mqdefault_6s.webp?du=3000&sqp=CNT9ycsG&rs=AOn4CLD1NjdkJaOAiWgxjX4q0FK_3duLlA', 'width': 320}], 'publishedTimeText': '6 hours ago', 'stats': {'views': 38708}, 'thumbnails': [{'height': 94, 'url': 'https://i.ytimg.com/vi/2MvyudXO0ew/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBrZ0klGmjCnefHb77Rc7VsKbv7vw', 'width': 168}, {'height': 110, 'url': 'https://i.ytimg.com/vi/2MvyudXO0ew/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAe8E1V6N-25O9Hrf0UwxKroTgsHA', 'width': 196}, {'height': 138, 'url': 'https://i.ytimg.com/vi/2MvyudXO0ew/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDHfnOGRdX6ZyR4-ALsOZr_i6UVog', 'width': 246}, {'height': 188, 'url': 'https://i.ytimg.com/vi/2MvyudXO0ew/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAI1zfKmAceJUNDggQ8ZHCYs8Z-Ng', 'width': 336}], 'title': 'FULL MATCH: AJ Styles vs. Shinsuke Nakamura | WWE Title Match: Greatest Royal Rumble 2018', 'videoId': '2MvyudXO0ew'}}, {'type': 'video', 'video': {'badges': [], 'isLiveNow': False, 'lengthSeconds': 2334, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/W4Fm008NKzk/mqdefault_6s.webp?du=3000&sqp=CNjrycsG&rs=AOn4CLDpRsyXSyn5Yv_fDwYwLmXsNjywow', 'width': 320}], 'publishedTimeText': '7 hours ago', 'stats': {'views': 78447}, 'thumbnails': [{'height': 94, 'url': 'https://i.ytimg.com/vi/W4Fm008NKzk/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBsqX4jDUyaGPlv3k0v8_yRdcxNBg', 'width': 168}, {'height': 110, 'url': 'https://i.ytimg.com/vi/W4Fm008NKzk/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBtzxPqlamClsBFqFI_wHs5fWAK9A', 'width': 196}, {'height': 138, 'url': 'https://i.ytimg.com/vi/W4Fm008NKzk/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCQPZVf7IT-jNsdg-XR6S9yRCEUMw', 'width': 246}, {'height': 188, 'url': 'https://i.ytimg.com/vi/W4Fm008NKzk/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBDTjaTEJwNJ99kXuQfRf9ltOhwTA', 'width': 336}], 'title': 'Massive pull-apart brawls: WWE Playlist', 'videoId': 'W4Fm008NKzk'}}, {'type': 'video', 'video': {'badges': [], 'isLiveNow': False, 'lengthSeconds': 522, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/FBpiehKFPeg/mqdefault_6s.webp?du=3000&sqp=COiHyssG&rs=AOn4CLBq68STVVrrP3iDMQiD15fjb6TP8w', 'width': 320}], 'publishedTimeText': '1 day ago', 'stats': {'views': 39549}, 'thumbnails': [{'height': 94, 'url': 'https://i.ytimg.com/vi/FBpiehKFPeg/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLD ...

# %%
df_capstone = pd.read_csv('data.csv')

# %%
df_capstone.head()
# Out:
#     type video.badges  video.isLiveNow  video.lengthSeconds  \
# 0  video           []            False                  196
# 1  video           []            False                 1297
# 2  video           []            False                 2334
# 3  video           []            False                  522
# 4  video           []            False                 5413
#
#                               video.movingThumbnails video.publishedTimeText  \
# 0  [{'height': 180, 'url': 'https://i.ytimg.com/a...             3 hours ago
# 1  [{'height': 180, 'url': 'https://i.ytimg.com/a...             6 hours ago
# 2  [{'height': 180, 'url': 'https://i.ytimg.com/a...             7 hours ago
# 3  [{'height': 180, 'url': 'https://i.ytimg.com/a...               1 day ago
# 4  [{'height': 180, 'url': 'https://i.ytimg.com/a...               1 day ago
#
#    video.stats.views                                   video.thumbnails  \
# 0               7224  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 1              38708  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 2              78447  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 3              39549  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 4            1067672  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
#
#                                          video.title video.videoId
# 0  Karmen Petrovic and Kali Armstrong battle in E...   QfWVpBzSZsA
# 1  FULL MATCH: AJ Styles vs. Shinsuke Nakamura | ...   2MvyudXO0ew
# 2            Massive pull-apart brawls: WWE Playlist   W4Fm008NKzk
# 3  Top 10 WWE NXT moments: WWE Top 10, Jan. 20, 2026   FBpiehKFPeg
# 4  FULL MATCH: 2025 Men’s Royal Rumble Match: Roy...   U0-D_wSStlk
